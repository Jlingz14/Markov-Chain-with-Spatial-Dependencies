# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_excel('covid_first_wave.xlsx')
df.tail(10)
# Out:
#               Region  2020-03-20 00:00:00  2020-03-21 00:00:00  \
# 12         Betsiboka                    0                    0
# 13        Analamanga                    3                    0
# 14             Itasy                    0                    0
# 15         Bongolava                    0                    0
# 16     Vakinakaratra                    0                    0
# 17  Matsiatra-ambony                    0                    0
# 18   Atsimo_Atsinana                    0                    0
# 19      Amoron_Mania                    0                    0
# 20   Alaotra_Mangoro                    0                    0
# 21        Atsinanana                    0                    0
#
#     2020-03-22 00:00:00  2020-03-23 00:00:00  2020-03-24 00:00:00  \
# 12                    0                    0                    0
# 13                    0                    9                    5
# 14                    0                    0                    0
# ...

# %%
# Définir la région comme l'index
df.set_index('Region', inplace=True)

# Déterminer le nombre de sous-graphiques
num_regions = len(df)
num_cols = 4
num_rows = math.ceil(num_regions / num_cols)

# Créer des sous-graphiques
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15,10), sharex=True)

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Tracer les données pour chaque région
for i, region in enumerate(df.index):
    df.loc[region].plot(kind='line',marker='.', ax=axes[i], title=f'Data for the Region {region}')
    axes[i].set_xlabel('Dated')
    axes[i].set_ylabel('New case')
    axes[i].grid(False)

# Supprimer les sous-graphiques vides
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Ajuster les espacements
plt.tight_layout()

# Afficher la figure
plt.savefig("Covid_per.jpg",dpi=350)
plt.show()
